# %%
from nsepy import get_history
from datetime import date
from nsepy import get_index_pe_history
import numpy as np
import matplotlib.pyplot as plot
infy = get_history(symbol="INFY",start=date(2015,1,1), end=date(2016,12,31))
#data[['Close']].plot()
tcs = get_history(symbol="TCS",start=date(2015,1,1), end=date(2016,12,31))
nifty = get_history(symbol="NIFTY IT",start=date(2015,1,1), end=date(2016,12,31),index= True)
infy.head()
#tcs.head()
#{nifty_fut = get_history(symbol="NIFTY IT",start=date(2015,1,1),end=date(2016,12,31),index=True,futures=True,)}
#nifty_fut
#np.convolve(tcs, np.ones((N,))/N, mode='valid')
#%matplotlib inline
#%pylab inline
#pylab.rcParams['figure.figsize'] = (15, 9)   # Change the size of plots
infy
tcs
nifty
#infy["Volume"].plot(grid = True)
# Out:
#                 Open      High       Low     Close    Volume      Turnover
# Date
# 2015-01-01  11214.80  11235.75  11166.35  11215.70   4246150  3.575100e+09
# 2015-01-02  11214.65  11399.10  11214.65  11372.10  10004862  9.645600e+09
# 2015-01-05  11369.35  11433.75  11186.95  11248.55   8858018  1.059000e+10
# 2015-01-06  11186.10  11186.10  10909.00  10959.90  12515739  1.364500e+10
# 2015-01-07  11013.20  11042.35  10889.55  10916.00  10976356  1.203440e+10
# 2015-01-08  11031.15  11058.15  10915.05  11018.15  12975117  1.485630e+10
# 2015-01-09  11058.05  11484.90  10932.20  11399.65  24812224  3.536420e+10
# 2015-01-12  11456.00  11565.85  11378.80  11543.65  16505074  1.712310e+10
# 2015-01-13  11545.25  11546.60  11437.95  11502.80  12511358  1.417510e+10
# 2015-01-14  11561.95  11631.55  11521.00  11614.30  12544558  1.438530e+10
# 2015-01-15  11672.30  11774.50  11575.10  11669.85  13882213  1.764560e+10
# ...

# %%
import numpy as np
infy = get_history(symbol="INFY",start=date(2015,1,1), end=date(2016,12,31))
infy
#np.convolve(infy["Close"], np.ones((13,))/13, mode='valid')

infy
#def runningMeanFast(x, N):
 #   return np.convolve(x, np.ones((N,))/N)[(N-1):]
#runningMeanFast(infy["Close"],28)
###########1##################
def running_mean(l, N):
    sum = 0
    result = list( 0 for x in l)

    for i in range( 0, N ):
        sum = sum + l[i]
        result[i] = sum / (i+1)

    for i in range( N, len(l) ):
        sum = sum - l[i-N] + l[i]
        result[i] = sum / N

    return result
running_mean(infy["Close"],28)
running_mean(tcs["Close"],28)
running_mean(nifty["Close"],28)
# Out:
# [11215.7,
#  11293.900000000001,
#  11278.783333333335,
#  11199.062500000002,
#  11142.45,
#  11121.733333333335,
#  11161.435714285715,
#  11209.2125,
#  11241.833333333334,
#  11279.08,
#  11314.604545454546,
#  11343.354166666666,
#  11366.384615384615,
#  11389.857142857143,
#  11418.113333333335,
#  11445.159375000001,
#  11471.04117647059,
#  11483.397222222224,
#  11500.563157894738,
#  11516.7425,
#  11531.409523809523,
#  11550.161363636364,
#  11568.15,
#  11583.597916666668,
#  11606.860000000002,
#  11632.286538461542,
#  11655.13888888889,
#  11673.27142857143,
#  11709.975000000002,
#  11745.685714285717,
#  11789.128571428575,
#  11843.675000000003,
#  11904.987500000003,
#  11965.903571428573,
#  12007.77142857143,
#  12043.044642857143,
#  12081.023214285715,
#  12117.417857142858,
#  12145.58392857143,
#  12177.560714285717,
#  12213.883928571431,
#  12248.48035714286,
#  12285.70178571429,
#  12317.121428571432,
#  12344.991071428574,
#  12371.019642857145,
# ...
